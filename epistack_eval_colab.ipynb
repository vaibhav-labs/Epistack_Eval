# %% [markdown]
# # Epistack Eval — one-click Colab demo
#
# Tests whether a knowledge base's rigor survives contact with a reasoner. Runs the **same instrument** across three starter shapes and one real 26-claim base, on two models.
#
# **Fastest look (no API key):** run the Setup cell, then the **Dry run** cell — it prints the report *shape* with placeholder numbers so you can see the structure instantly.
#
# **Real run:** paste an Anthropic API key in the Key cell, then run any case cell. The real, full-size base is `covid_large`.
#
# Most interesting code to inspect: the `covid_large` base and its **hidden answer key** (the two correlated clusters), the **Part B** double-counting probe (`run_doublecount`), and the **Part C** retracted-claim probe (`run_retraction`).

# %% [markdown]
# ## Setup — clone the repo and install the SDK

# %%
# !git clone https://github.com/vaibhav-labs/Epistack_Eval.git 2>/dev/null || (cd Epistack_Eval && git pull)
# %cd Epistack_Eval
# !pip -q install anthropic

# %% [markdown]
# ## Dry run — see the report shape with NO key (placeholders, not results)

# %%
# !python3 epistack_eval.py --dry-run

# %% [markdown]
# ## Key — paste your Anthropic API key to enable real runs

# %%
import os, getpass
os.environ['ANTHROPIC_API_KEY'] = getpass.getpass('ANTHROPIC_API_KEY: ')

# %% [markdown]
# ## The headline: the real 26-claim base (`covid_large`)
# Built by deep research on two models, reconciled, then **stripped of correlation flags and strengths** before the instrument saw it. Watch Part B independently re-derive the five-claim Wuhan-cluster double-count. Expect the effect to fire; expect the magnitude to move run to run.

# %%
# !python3 epistack_eval.py --case covid_large --model claude-opus-4-8

# %%
# !python3 epistack_eval.py --case covid_large --model claude-sonnet-4-6

# %% [markdown]
# ## It travels: the three starter shapes
# contested (covid), settled (blackholes), ill-posed (eggs) — same instrument, only the base and warranted shape change.

# %%
# !python3 epistack_eval.py --case covid      --model claude-opus-4-8
# !python3 epistack_eval.py --case blackholes --model claude-opus-4-8
# !python3 epistack_eval.py --case eggs       --model claude-opus-4-8

# %% [markdown]
# ## The base is an input: run it on a base the author never touched
# `external_base_template.json` is the schema. Replace its placeholder claims with a real base (another entrant's, an FLF base, or one built by the `covid_large` pipeline) and point `--kb-file` at it — no Python editing needed.

# %%
# Plumbing check on the template (placeholders, not a result):
# !python3 epistack_eval.py --kb-file external_base_template.json --dry-run
